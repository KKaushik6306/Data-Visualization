# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df = pd.DataFrame(np.random.randn(1000),index=pd.date_range('2019-06-07',periods=1000),columns=['Values'])
df
# Out:
#               Values
# 2019-06-07  1.229930
# 2019-06-08  0.146775
# 2019-06-09 -0.863203
# 2019-06-10 -0.819757
# 2019-06-11 -0.087840
# ...              ...
# 2022-02-26 -0.510076
# 2022-02-27 -0.455646
# 2022-02-28  1.072954
# 2022-03-01 -1.128164
# 2022-03-02 -0.502140
#
# [1000 rows x 1 columns]

# %%
ts = pd.Series(np.random.randn(1000),index=pd.date_range('2019-06-07',periods=1000))
ts
# Out:
# 2019-06-07   -0.843132
# 2019-06-08    0.375510
# 2019-06-09    1.321508
# 2019-06-10    0.337581
# 2019-06-11   -0.172215
#                 ...
# 2022-02-26    1.313458
# 2022-02-27   -0.550759
# 2022-02-28   -1.309587
# 2022-03-01    1.790235
# 2022-03-02    0.752774
# Freq: D, Length: 1000, dtype: float64

# %%
df['Values'] = df['Values'].cumsum()
df
# Out:
#                Values
# 2019-06-07   1.229930
# 2019-06-08   1.376705
# 2019-06-09   0.513502
# 2019-06-10  -0.306255
# 2019-06-11  -0.394095
# ...               ...
# 2022-02-26 -70.507847
# 2022-02-27 -70.963493
# 2022-02-28 -69.890539
# 2022-03-01 -71.018703
# 2022-03-02 -71.520843
#
# [1000 rows x 1 columns]

# %%
df.plot()

# %%
df.plot(figsize=(20,10))

# %%
plt.plot(df)

# %%
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.plot(figsize=(15,5))
plt.title('Iris Dataset')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')
